# %%
import sqlite3

# %%
# DBファイルのパス
path = ''

# google colabの場合
# path = '/content/'

# DBファイル
db_name = 'test_db'

# db接続の確率
# dbファイルがぞんざいしない場合は新規作成される
conn = sqlite3.connect(path + db_name)

# dbの接続を閉じる
conn.close()

# %%
path = ''  # DBファイル保存先パス
db_name = 'google.db'  # DBファイル

# db接続オブジェクトの作成
conn = sqlite3.connect(path + db_name)

# SQL(RDBを操作するための言語)を実行するためのカーソルオブジェクトを取得
cur = conn.cursor()

# SQL文を作成
# テーブルの作成
sql = 'CREATE TABLE google (id INT, name TEXT, language TEXT, price REAL);'

# SQL文を実行
cur.execute(sql)

# DBへの接続を閉じる
conn.close()

# %%
path = ''  # DBファイル保存先パス
db_name = 'google.db'  # DBファイル

# db接続オブジェクトの作成
conn = sqlite3.connect(path + db_name)

# SQL(RDBを操作するための言語)を実行するためのカーソルオブジェクトを取得
cur = conn.cursor()

# SQL文を作成
# テーブルの作成
sql = "INSERT INTO google (id, name, price) VALUES (1, '370z', 7000000);"

# SQL文を実行
cur.execute(sql)

# DBへの接続を閉じる
conn.close()
